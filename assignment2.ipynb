# %%
import matplotlib.pyplot as plt##nikhil sai 21blc1382
import numpy as np
import pandas as pd
import seaborn as sn

# %%
print(sn.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sn.load_dataset('car_crashes')###nikhil sai 21blc1382
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT
# ...

# %%
df.tail(10)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 44   11.3     4.859    1.808           9.944       10.848       809.38
# 45   13.6     4.080    4.080          13.056       12.920       716.20
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# ...

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
sn.lineplot(data=df,x='ins_premium',y='ins_losses',color="red")
# Out:
# <Axes: xlabel='ins_premium', ylabel='ins_losses'>

# %%
sn.barplot(data=df,x='abbrev',y='ins_losses',color="red",width=2.0,hue='ins_premium')
# Out:
# <Axes: xlabel='abbrev', ylabel='ins_losses'>

# %%
sn.countplot(x='abbrev',data=df)
# Out:
# <Axes: xlabel='abbrev', ylabel='count'>

# %%
sn.jointplot(data=df,x='ins_premium',y='ins_losses')
plt.grid(True)

# %%
sn.boxplot(data=df,x='ins_premium',y='ins_losses',width=50)
plt.grid(True)

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-26-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
sn.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.abbrev.value_counts()
# Out:
# AL    1
# PA    1
# NV    1
# NH    1
# NJ    1
# NM    1
# NY    1
# NC    1
# ND    1
# OH    1
# OK    1
# OR    1
# RI    1
# MT    1
# SC    1
# SD    1
# TN    1
# TX    1
# UT    1
# VT    1
# VA    1
# WA    1
# WV    1
# WI    1
# NE    1
# MO    1
# AK    1
# ID    1
# AZ    1
# AR    1
# CA    1
# CO    1
# CT    1
# DE    1
# DC    1
# FL    1
# GA    1
# HI    1
# IL    1
# MS    1
# IN    1
# IA    1
# KS    1
# KY    1
# LA    1
# ME    1
# MD    1
# MA    1
# MI    1
# MN    1
# WY    1
# Name: abbrev, dtype: int64

# %%
df.isnull().any()
# Out:
# total             False
# speeding          False
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# abbrev            False
# dtype: bool

# %%
sn.boxplot(df.alcohol)
# Out:
# <Axes: >

# %%
x=df.iloc[:,7:]
x
# Out:
#    abbrev
# 0      AL
# 1      AK
# 2      AZ
# 3      AR
# 4      CA
# 5      CO
# 6      CT
# 7      DE
# 8      DC
# 9      FL
# 10     GA
# 11     HI
# 12     ID
# 13     IL
# 14     IN
# 15     IA
# 16     KS
# 17     KY
# 18     LA
# 19     ME
# 20     MD
# 21     MA
# 22     MI
# 23     MN
# 24     MS
# 25     MO
# 26     MT
# 27     NE
# 28     NV
# 29     NH
# 30     NJ
# 31     NM
# 32     NY
# 33     NC
# 34     ND
# 35     OH
# 36     OK
# 37     OR
# 38     PA
# 39     RI
# 40     SC
# 41     SD
# 42     TN
# 43     TX
# 44     UT
# 45     VT
# 46     VA
# 47     WA
# 48     WV
# 49     WI
# 50     WY

# %%
sn.scatterplot(data=df,x='ins_premium',y='ins_losses')
# Out:
# <Axes: xlabel='ins_premium', ylabel='ins_losses'>

# %%
sn.pairplot(data=df)
